# %% [markdown]
# # Init stuffs

# %% [markdown]
# ### Imports

# %%
from math import prod

# %% [markdown]
# ### Input data

# %%
filename = "./input_1.txt"

with open(file=filename) as f:
    input_data_pt1 = f.read().splitlines()

# %% [markdown]
# # Pt. 1

# %%
def transpose_list_of_lists(listlist: list[list]) -> list[list]:
    new_listlist = []
    for i in range(len(listlist[0])):
        new_listlist.append([x[i] for x in listlist])
    return new_listlist

def calculate_order(order: list) -> int:
    operand = order[-1]
    values = [int(x) for x in order[:-1]]
    if operand == "*":
        return prod(values)
    elif operand == "+":
        return sum(values)
    else:
        print(f"Unknown operand {operand}")

# %%
instructions = []
for line in input_data_pt1:
    instructions.append([x for x in line.split(" ") if x])
logic_instructions = transpose_list_of_lists(instructions)

all_orders = []
for instruction in logic_instructions:
    all_orders.append(calculate_order(order=instruction))

print(f"Sum of all orders is {sum(all_orders)}")
print(f"Based on orders {logic_instructions}")
# Out:
# Sum of all orders is 6417439773370
# Based on orders [['617', '478', '48', '44', '*'], ['828', '337', '61', '55', '+'], ['937', '998', '331', '14', '*'], ['2344', '3442', '426', '12', '+'], ['145', '618', '23', '6', '+'], ['37', '226', '8168', '6495', '+'], ['83', '22', '997', '171', '*'], ['845', '45', '19', '65', '*'], ['37', '656', '737', '765', '*'], ['7', '66', '93', '11', '*'], ['882', '47', '15', '8', '+'], ['928', '653', '712', '795', '+'], ['48', '36', '51', '68', '*'], ['929', '72', '8', '4', '+'], ['79', '821', '165', '657', '+'], ['69', '27', '94', '14', '*'], ['119', '957', '538', '618', '+'], ['36', '8263', '7915', '6148', '+'], ['95', '63', '57', '626', '*'], ['7', '13', '88', '91', '+'], ['12', '515', '991', '525', '+'], ['2', '1', '44', '93', '+'], ['778', '358', '46', '27', '+'], ['7', '8', '3', '76', '*'], ['9', '476', '258', '313', '+'], ['1897', '1485', '66', '79', '+'], ['361', '662', '772', '76', '*'], ['1', '293', '252', '193', '*'], ['988', '775', '291', '7', '+'], ['84', '65', '73', '94', '+'], ['86', '88', '43', '93', '*'], ['978', '541', '745', '459', '*'], ['5', '61', '25', '17', '*'], ['737', '851', '69', '93', '+'], ['3', '52', '75', '22', '*'], ['973', '487', '614', '67', '+'], ['3', '72', '68', '74', '*'], ['518', '775', '557', '77', '*'], ['31', '98', '83', '82', '*'], ['3', '17', '79', '23', '*'], ['57', '156', '284', '819', '+'], ['92', '427', '361', '929', '*'], ['61', '91', '16', '54', '*'], ['9488', '2892', '4367', '5872', '+'], ['491', '682', '89', '14', '*'], ['6', '89', '12', '83', '*'], ['86', '483', '951', '152', '*'], ['238', '239', '665', '18', '*'], ['53', '14', '35', '54', '+'], ['841', '491', '698', '557', '*'], ['79', '51', '44', '618', '*'], ['664', '579', '594', '369', '+'], ['22', '76', '15', '6', '*'], ['9', '2', '18', '734', '+'], ['84', '59', '56', '67', '*'], ['8', '4', '2', '45', '+'], ['368', '311', '948', '84', '+'], ['982', '996', '276', '142', '*'], ['5', '19', '464', '727', '*'], ['9', '96', '8884', '3555', '+'], ['93', '84', '82', '8', '+'], ['653', '428', '87', '48', '+'], ['52', '551', '631', '193', '*'], ['93', '785', '434', '513', '+'], ['66', '81', '995', '117', '*'], ['5', '48', '932', '446', '+'], ['81', '123', '986', '287', '+'], ['688', '158', '6556', '1852', '+'], ['25', '35', '554', '828', '*'], ['886', '556', '792', '215', '*'], ['67', '96', '557', '389', '*'], ['8', '69', '86', '24', '*'], ['462', '324', '271', '451', '+'], ['9', '3', '1', '52', '+'], ['1', '5', '29', '69', '*'], ['473', '961', '68', '9', '*'], ['3753', '3222', '3728', '749', '+'], ['391', '492', '57', '54', '*'], ['929', '436', '729', '515', '*'], ['236', '948', '584', '61', '*'], ['9', '156', '874', '5374', '+'], ['98', '73', '263', '494', '+'], ['9', '44', '83', '17', '*'], ['6139', '6856', '233', '623', '+'], ['5', '84', '121', '942', '*'], ['9', '54', '97', '13', '+'], ['2', '89', '83', '51', '+'], ['67', '91', '49', '89', '*'], ['6', '91', '57', '87', '+'], ['9', '21', '83', '79', '*'], ['2739', '3297', '135', '166', '+'], ['1189', '3353', '861', '3', '+'], ['43', '43', '14', '31', '*'], ['14', '76', '67', '42', '+'], ['49', '54', '941', '824', '*'], ['26', '16', '91', '96', '+'], ['5', '4', '64', '42', '+'], ['2661', '6197', '8497', '8413', '+'], ['73', '38', '69', '79', '*'], ['588', '734', '484', '97', '*'], ['291', '959', '818', '73', '+'], ['296', '947', '7', '9', '*'], ['84', '2', '4', '2', '+'], ['52', '678', '685', '713', '+'], ['382', '145', '63', '1', '*'], ['5891', '5191', '7929', '4293', '+'], ['95', '13', '78', '5', '+'], ['9', '2', '9', '92', '*'], ['9', '1', '478', '325', '+'], ['477', '622', '943', '476', '*'], ['1', '73', '95', '11', '+'], ['3', '72', '486', '7199', '+'], ['174', '617', '199', '369', '*'], ['595', '881', '888', '444', '+'], ['69', '77', '51', '3', '*'], ['88', '386', '1734', '7771', '+'], ['16', '38', '69', '78', '*'], ['56', '76', '561', '193', '*'], ['29', '65', '81', '81', '*'], ['6', '14', '56', '16', '*'], ['6', '87', '61', '42', '+'], ['482', '37', '79', '84', '+'], ['8817',  ...

# %% [markdown]
# # Init pt. 2

# %% [markdown]
# ### More imports?

# %% [markdown]
# ### Input data (again)

# %%
filename = "./input_1.txt"

with open(file=filename) as f:
    input_data_pt2 = f.read().splitlines()

# %% [markdown]
# # Pt. 2

# %%
# Pretty happy about this function, though I already lost important info before this step. Need to redo reading the data

# def transpose_list_of_numbers(numbers: list[int]) -> list[int]:
#     str_numbers = [str(num) for num in numbers]

#     new_numbers = []
#     for i in range(max(len(str_numbers[0]),len(str_numbers[-1]))):
#         new_numbers.append("".join([num[i] for num in str_numbers if len(num)>=i+1]))
#     return new_numbers

# %%
def read_cephalopod_numbers(listlist: list[list]) -> list[str]:
    bounds = [i for i, value in enumerate(listlist[-1]) if value != " "] + [len(listlist[-1])+1]
    instructions = []
    for number in range(len(bounds[:-1])):
        cephalopod_numbers = []
        for i in range(bounds[number], bounds[number+1]-1):
            cephalopod_numbers.append("".join([l[i] for l in listlist[:-1] if l[i] != " "]))
        instructions.append(cephalopod_numbers+[listlist[-1][bounds[number]]])
    return instructions

# %%
cephalopod_instructions = read_cephalopod_numbers(input_data_pt2)
all_orders = []
for instruction in cephalopod_instructions:
    all_orders.append(calculate_order(order=instruction))

print(f"Sum of all orders is {sum(all_orders)}")
print(f"Based on orders {cephalopod_instructions}")
# Out:
# Sum of all orders is 11044319475191
# Based on orders [['6444', '1784', '78', '*'], ['83', '2365', '8715', '+'], ['993', '3931', '7814', '*'], ['2341', '3422', '446', '42', '+'], ['1626', '413', '58', '+'], ['3286', '7214', '669', '85', '+'], ['8291', '3297', '71', '*'], ['8', '4416', '5595', '*'], ['3677', '7536', '675', '*'], ['691', '7631', '*'], ['8', '841', '2758', '+'], ['9677', '2519', '8325', '+'], ['4356', '8618', '*'], ['9', '27', '9284', '+'], ['7816', '9265', '157', '+'], ['6291', '9744', '*'], ['1956', '1531', '9788', '+'], ['876', '291', '3614', '6358', '+'], ['9656', '5372', '6', '*'], ['189', '7381', '+'], ['1595', '2192', '515', '+'], ['2149', '43', '+'], ['73', '7542', '8867', '+'], ['7837', '6', '*'], ['9423', '751', '683', '+'], ['1167', '8469', '98', '75', '+'], ['367', '6677', '1226', '*'], ['1221', '959', '323', '*'], ['972', '879', '8517', '+'], ['8679', '4534', '+'], ['8849', '6833', '*'], ['9574', '7445', '8159', '*'], ['621', '5157', '*'], ['7869', '3593', '71', '+'], ['3572', '252', '*'], ['946', '7816', '3747', '+'], ['767', '3284', '*'], ['575', '1757', '8577', '*'], ['3988', '1832', '*'], ['172', '3793', '*'], ['128', '5581', '7649', '+'], ['439', '9262', '2719', '*'], ['6915', '1164', '*'], ['9245', '4838', '8967', '8272', '+'], ['4681', '9894', '12', '*'], ['818', '6923', '*'], ['8491', '6855', '312', '*'], ['226', '3361', '8958', '*'], ['5135', '3454', '+'], ['8465', '4995', '1187', '*'], ['7546', '9141', '8', '*'], ['6553', '6796', '4949', '+'], ['2716', '265', '*'], ['9217', '83', '4', '